# %%
import spacy

nlp = spacy.load('en_core_web_sm')
nlp.pipe_names

nlpEs = spacy.load('es_core_news_sm')
nlpEs.pipe_names
# Out:
# ['tok2vec', 'morphologizer', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
#Imprimimos el tipo de cada uno de los token que componen la frase
doc = nlp("He comido una amburguesa grasienta.")
for token in doc:
    print(token.text, "-->", token.pos_)
# Out:
# He --> PRON
# comido --> VERB
# una --> PROPN
# amburguesa --> PROPN
# grasienta --> PROPN
# . --> PUNCT

# %%
#Imprimimos las dependencias de cada uno de los token que componen la frase
for token in doc:
    print(token.text, "-->", token.dep_)

#Imprimimos el significado de cada una de las etiquetas
spacy.explain("nsubj"), spacy.explain("ROOT"), spacy.explain("aux"), spacy.explain("advcl"), spacy.explain("dobj"),
# Out:
# He --> nsubj
# went --> ROOT
# to --> aux
# play --> advcl
# basketball --> dobj
# nsub..: nominal subject
# ('root', 'auxiliary', 'adverbial clause modifier', 'direct object')

# %%
#Imprimimos las dependencias de forma gráfica
from spacy import displacy
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="056c9b1dd53d453ca4a5c1463f7fef75-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">went</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...

# %%
doc2 = nlp("He went to play basketball. He ate a burger. She drank a coke.")
displacy.render(doc2, style='dep', jupyter=True)

for token in doc2:
    print(token.text, "-->", token.dep_)
    print(token.lemma_)
    if token.n_rights>0 and token.n_lefts>0:
        print(" ", "CHRILDREN:")
        
        print(" ", "(left):")
        for subtoken in token.lefts:
            print("    ", subtoken)
            
        print(" ", "(left):")
        for subtoken in token.rights:
            print("    ", subtoken)
    print()
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ec75dc1045964af89936fca7d867b9c6-0" class="displacy" width="2325" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">went</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
# ...
